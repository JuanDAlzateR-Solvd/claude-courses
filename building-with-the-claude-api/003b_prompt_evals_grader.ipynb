# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Solution\n\nHere's a Python function that extracts the AWS region from an S3 bucket URL:\n\n```python\nimport re\n\ndef extract_region_from_s3_url(url):\n    \"\"\"\n    Extracts the AWS region from an S3 bucket URL.\n    \n    Expected formats:\n    - s3://bucket-name.region.amazonaws.com\n    - https://bucket-name.s3.region.amazonaws.com\n    - https://s3.region.amazonaws.com/bucket-name\n    \n    Args:\n        url (str): The S3 bucket URL\n        \n    Returns:\n        str: The AWS region, or None if not found\n    \"\"\"\n    # Pattern for s3://bucket-name.region.amazonaws.com\n    pattern1 = r's3://[^.]+\\.([a-z0-9\\-]+)\\.amazonaws\\.com'\n    \n    # Pattern for https://bucket-name.s3.region.amazonaws.com\n    pattern2 = r'https?://[^.]+\\.s3[.-]([a-z0-9\\-]+)\\.amazonaws\\.com'\n    \n    # Pattern for https://s3.region.amazonaws.com/bucket-name\n    pattern3 = r'https?://s3[.-]([a-z0-9\\-]+)\\.amazonaws\\.com'\n    \n    for pattern in [pattern1, pattern2, pattern3]:\n        match = re.search(pattern, url)\n        if match:\n            return match.group(1)\n    \n    return None\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_urls = [\n        \"s3://my-bucket.us-east-1.amazonaws.com\",\n        \"s3://my-bucket.eu-west-1.amazonaws.com\",\n        \"https://my-bucket.s3.us-west-2.amazonaws.com\",\n        \"https://my-bucket.s3-ap-southeast-1.amazonaws.com\",\n        \"https://s3.ca-central-1.amazonaws.com/my-bucket\",\n        \"https://s3-sa-east-1.amazonaws.com/my-bucket\",\n    ]\n    \n    for url in test_urls:\n        region = extract_region_from_s3_url(url)\n        print(f\"URL: {url}\")\n        print(f\"Region: {region}\\n\")\n```\n\n**Output:**\n```\nURL: s3://my-bucket.us-east-1.amazonaws.com\nRegion: us-east-1\n\nURL: s3://my-bucket.eu-west-1.amazonaws.com\nRegion: eu-west-1\n\nURL: https://my-bucket.s3.us-west-2.amazonaws.com\nRegion: us-west-2\n\nURL: https://my-bucket.s3-ap-southeast-1.amazonaws.com\nRegion: ap-southeast-1\n\nURL: https://s3.ca-central-1.amazonaws.com/my-bucket\nRegion: ca-central-1\n\nURL: https://s3-sa-east-1.amazonaws.com/my-bucket\nRegion: sa-east-1\n```\n\n## Key Features:\n\n1. **Multiple Format Support**: Handles various S3 URL formats (s3://, https://, virtual-hosted, path-style)\n2. **Regex Pattern Matching**: Uses three patterns to match different S3 URL styles\n3. **Region Validation**: Matches AWS region naming conventions (lowercase letters, numbers, hyphens)\n4. **Return Value**: Returns the region string or `None` if not found\n5. **Well-documented**: Includes docstring explaining usage and supported formats\n\n## Simplified Version:\n\nIf you only need to handle the exact format specified (`s3://bucket-name.region.amazonaws.com`):\n\n```python\nimport re\n\ndef extract_region_from_s3_url(url):\n    \"\"\"Extracts AWS region from S3 URL: s3://bucket-name.region.amazonaws.com\"\"\"\n    match = re.search(r's3://[^.]+\\.([a-z0-9\\-]+)\\.amazonaws\\.com', url)\n    return match.group(1) if match else None\n```",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS region from an S3 bucket URL in the format 's3://bucket-name.region.amazonaws.com'. The function should return the region string."
#     },
#     "score": 8,
#     "reasoning": "The solution correctly solves the original problem and goes beyond it with thoughtful additions. The core logic is sound and well-tested. However, the regex patterns are slightly too permissive for strict AWS region validation, and the lack of input validation is a minor oversight. The solution demonstrates good software engineering practices with documentation and examples, but adds complexity beyond the stated requirements. Overall, this is a solid, production-ready solution with minor room for improvement in edge case handling."
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object representing an IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ReadOnlyAccessToMyDataBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::my-data-bucket\",\n        \"arn:aws:s3:::my-data-bucket/*\"\n      ]\n    }\n  ]\n}\n```\n\n## Explanation of Key Fields\n\n| Field | Description |\n|-------|-------------|\n| **Version** | Policy language version (required) |\n| **Effect** | \"Allow\" grants the permissions; \"Deny\" would restrict them |\n| **Action** | `s3:ListBucket` - lists objects in the bucket<br>`s3:GetObject` - reads objects<br>`s3:GetObjectVersion` - accesses object versions |\n| **Resource** | Two ARNs required:<br>- `arn:aws:s3:::my-data-bucket` - for bucket operations<br>- `arn:aws:s3:::my-data-bucket/*` - for object operations |\n| **Sid** | Optional but recommended statement ID for clarity |\n\n## Usage\nAttach this policy to an IAM user, role, or group to grant read-only access to the 'my-data-bucket' S3 bucket.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy granting read-only access to a specific S3 bucket named 'my-data-bucket'. Include the necessary Effect, Action, and Resource fields."
#     },
#     "score": 8,
#     "reasoning": "The solution provides a well-structured, production-ready IAM policy that directly addresses the task requirements. The JSON is syntactically correct, the ARN structure is accurate, and the explanation is clear. The inclusion of GetObjectVersion is slightly over-specified for 'read-only' access but represents a reasonable interpretation. The policy follows AWS best practices with a descriptive Sid and proper Version declaration. Minor improvements could include clarifying optional actions and documenting edge cases, but these do not detract from the core solution's correctness."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regex\n\nHere's the correct regular expression:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Explanation\n\n| Component | Purpose |\n|-----------|---------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix required for EC2 instance IDs |\n| `[0-9a-f]` | Character class matching hexadecimal digits (0-9, a-f) |\n| `{17}` | Exactly 17 hexadecimal characters |\n| `$` | End of string anchor |\n\n## Examples\n\n### Valid matches:\n```\ni-0a1b2c3d4e5f67890\ni-1234567890abcdef0\ni-0000000000000000a\n```\n\n### Invalid (won't match):\n```\ni-0a1b2c3d4e5f6g7h8  (contains 'g' and 'h')\ni-0a1b2c3d4e5f6789   (only 16 characters)\n0a1b2c3d4e5f678901   (missing 'i-' prefix)\n```\n\n## Implementation Examples\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{17}$'\nresult = re.match(pattern, 'i-0a1b2c3d4e5f67890')\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nconst isValid = pattern.test('i-0a1b2c3d4e5f67890');\n```\n\n**Case-insensitive variant** (if uppercase is also allowed):\n```regex\n^i-[0-9a-fA-F]{17}$\n```",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS EC2 instance IDs, which follow the pattern of 'i-' followed by 17 hexadecimal characters (e.g., i-0a1b2c3d4e5f6g7h8)."
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly solves the technical problem with a valid regex pattern and provides excellent documentation. The pattern properly validates the 'i-' prefix and enforces exactly 17 hexadecimal characters. However, the solution could have been slightly more thorough by explicitly noting the error in the original task description and providing guidance on which variant to use (lowercase-only vs. case-insensitive). Despite this minor gap, the solution is highly practical and production-ready."
#   }
# ]
